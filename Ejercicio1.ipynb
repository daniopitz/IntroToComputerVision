# %% [markdown]
# # Ejercicio 1
#
# Superponer las imagenes left.jpg y right.jpg y contruir una panorámica (stitching)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randrange

img1 = cv2.imread('Right.jpeg')

img1_grey = cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

img2 = cv2.imread('Left.jpeg')

img2_grey = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)) #Imagen 1

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)) #Imagen 2
